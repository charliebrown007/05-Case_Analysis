# %% [markdown]
# # Análisis de datos: FIFA 23

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data

# %%
d_team = pd.read_csv("fullteam_df.csv")
d_player = pd.read_csv("players_fifa23.csv")

# %% [markdown]
# ### Visualización y transformación para "d_team"

# %%
d_team.tail()
# Out:
#         ID              Name  Overall  Attack  Midfield  Defence  IntPrestige  \
# 42  110081  Northern Ireland       70      66        70       72            2
# 43    1334           Finland       70      71        71       67            3
# 44    1413          China PR       70      71        69       70            3
# 45    1341           Iceland       69      69        68       68            2
# 46  111473       New Zealand       67      69        66       67            2
#
#     Players  StartingAverageAge  AllTeamAverageAge
# 42       26                28.6               28.7
# 43       26                28.3               27.1
# 44       26                30.3               30.4
# 45       26                25.2               26.4
# 46       26                25.6               25.2

# %%
d_team.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  47 non-null     int64
#  1   Name                47 non-null     object
#  2   Overall             47 non-null     int64
#  3   Attack              47 non-null     int64
#  4   Midfield            47 non-null     int64
#  5   Defence             47 non-null     int64
#  6   IntPrestige         47 non-null     int64
#  7   Players             47 non-null     int64
#  8   StartingAverageAge  47 non-null     float64
#  9   AllTeamAverageAge   47 non-null     float64
# dtypes: float64(2), int64(7), object(1)
# memory usage: 3.8+ KB

# %%
d_team.nunique().reset_index()
# Out:
#                 index   0
# 0                  ID  47
# 1                Name  47
# 2             Overall  16
# 3              Attack  19
# 4            Midfield  18
# 5             Defence  16
# 6         IntPrestige  10
# 7             Players   2
# 8  StartingAverageAge  28
# 9   AllTeamAverageAge  26

# %%
d_team.rename(columns = {'Name':'Country'}, inplace = True)

# %%
d_team.head()
# Out:
#      ID    Country  Overall  Attack  Midfield  Defence  IntPrestige  Players  \
# 0  1370     Brazil       85      85        85       83           10       26
# 1  1337    Germany       84      84        85       82           10       26
# 2  1369  Argentina       84      86        84       82            9       26
# 3  1318    England       83      86        83       83            8       26
# 4  1325    Belgium       83      84        81       79            8       26
#
#    StartingAverageAge  AllTeamAverageAge
# 0                28.6               27.6
# 1                27.4               26.5
# 2                29.4               27.6
# 3                26.6               26.1
# 4                28.2               27.6

# %% [markdown]
# Cada fila del dataset "d_tema" representa las caracterísiticas futbolísticas de un pais definido por su "ID" único. No existen valores vacíos (null) y los tipos de variables están asignados correctamente.

# %% [markdown]
# ### Visualización y transformación para "d_player"

# %%
d_player.head()
# Out:
#        ID            Name                    FullName  Age  Height  Weight  \
# 0  158023        L. Messi                Lionel Messi   35     169      67
# 1  165153      K. Benzema               Karim Benzema   34     187      81
# 2  188545  R. Lewandowski          Robert Lewandowski   33     185      81
# 3  190871       Neymar Jr  Neymar da Silva Santos Jr.   30     175      68
# 4  192119     T. Courtois            Thibaut Courtois   30     199      96
#
#                                            PhotoUrl Nationality  Overall  \
# 0  https://cdn.sofifa.net/players/158/023/23_60.png   Argentina       91
# 1  https://cdn.sofifa.net/players/165/153/23_60.png      France       91
# 2  https://cdn.sofifa.net/players/188/545/23_60.png      Poland       91
# 3  https://cdn.sofifa.net/players/190/871/23_60.png      Brazil       91
# 4  https://cdn.sofifa.net/players/192/119/23_60.png     Belgium       91
#
#    Potential  ...  LMRating  CMRating  RMRating LWBRating CDMRating RWBRating  \
# 0         91  ...        91        87        91        67        65        67
# 1         91  ...        89        84        89        67        67        67
# 2         91  ...        86        83        86        67        69        67
# 3         91  ...        91        85        91        69        66        69
# 4         92  ...        34        36        34        32        34        32
#
#   LBRating CBRating  RBRating GKRating
# 0       62       53        62       22
# 1       63       58        63       21
# 2       64       63        64       22
# 3       65       54        65       23
# 4       32       32        32       91
#
# [5 rows x 82 columns]

# %% [markdown]
# Dimensiones del dataset

# %%
d_player.shape
# Out:
# (1221, 82)

# %% [markdown]
# No existen valores vacíos (null)

# %%
d_player.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# Dado que el número de valores únicos en la columna ID (1220) no es el mismo que el número de filas del dataset (1221), entonces existe una valor que está duplicado.

# %%
d_player.nunique().reset_index()
# Out:
#         index     0
# 0          ID  1220
# 1        Name  1213
# 2    FullName  1220
# 3         Age    24
# 4      Height    41
# ..        ...   ...
# 77  RWBRating    68
# 78   LBRating    68
# 79   CBRating    69
# 80   RBRating    68
# 81   GKRating    43
#
# [82 rows x 2 columns]

# %%
d_player[d_player["ID"].duplicated(keep = False)]
# Out:
#         ID           Name              FullName  Age  Height  Weight  \
# 64  241461  Ferran Torres  Ferran Torres García   22     184      77
# 85  241461  Ferran Torres  Ferran Torres García   22     184      77
#
#                                             PhotoUrl Nationality  Overall  \
# 64  https://cdn.sofifa.net/players/241/461/23_60.png       Spain       85
# 85  https://cdn.sofifa.net/players/241/461/23_60.png       Spain       85
#
#     Potential  ...  LMRating  CMRating  RMRating LWBRating CDMRating  \
# 64         90  ...        86        79        86        65        61
# 85         90  ...        86        79        86        65        61
#
#    RWBRating LBRating CBRating  RBRating GKRating
# 64        65       61       52        61       22
# 85        65       61       52        61       22
#
# [2 rows x 82 columns]

# %% [markdown]
# Eliminar registros duplicados del dataset

# %%
d_player.drop_duplicates(subset = 'ID', keep = 'first', inplace = True, ignore_index = True)

# %% [markdown]
# Nueva verificación

# %%
d_player.shape
# Out:
# (1220, 82)

# %%
d_player['ID'].nunique()
# Out:
# 1220

# %% [markdown]
# ### Análisis para "d_team"

# %%
d_team.tail()
# Out:
#         ID           Country  Overall  Attack  Midfield  Defence  IntPrestige  \
# 42  110081  Northern Ireland       70      66        70       72            2
# 43    1334           Finland       70      71        71       67            3
# 44    1413          China PR       70      71        69       70            3
# 45    1341           Iceland       69      69        68       68            2
# 46  111473       New Zealand       67      69        66       67            2
#
#     Players  StartingAverageAge  AllTeamAverageAge
# 42       26                28.6               28.7
# 43       26                28.3               27.1
# 44       26                30.3               30.4
# 45       26                25.2               26.4
# 46       26                25.6               25.2

# %% [markdown]
# TAREAS
# - El puntaje pueden ser representado en un diagrama de dispersión.
# - Los paises pueden agruparse en un conjuntos más grandes, por ejemplo: continentes.

# %%
(d_team['IntPrestige'].value_counts().
        reset_index().
        rename(columns = {'index':'IntPrestige','IntPrestige':'Count'}).
        sort_values(by = 'Count', ascending = False)
)
# Out:
#    IntPrestige  Count
# 0            5     11
# 1            4      8
# 2            6      6
# 3            3      5
# 4            8      4
# 5            2      4
# 6           10      3
# 7            9      3
# 8            7      2
# 9            1      1

# %% [markdown]
# #### Top 5 según valoraciones

# %%
d_team['Country'].nunique()
# Out:
# 47

# %%
col_title = d_team.loc[:,'Overall':'Defence'].columns.tolist()

d_team01 = pd.DataFrame([])

top = 5

for i in col_title:
    
    aux01 = (d_team.loc[:,['Country',i]].
                 sort_values(by = i, ascending = False, ignore_index = True).
                 head(top))
    
    aux02 = pd.melt(frame = aux01, id_vars = ['Country'], value_vars = i, var_name = 'Type').reset_index()

    d_team01 = pd.concat([d_team01,aux02], ignore_index = True)
        
print(type(d_team01))
d_team01
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     index      Country      Type  value
# 0       0       Brazil   Overall     85
# 1       1    Argentina   Overall     84
# 2       2      Germany   Overall     84
# 3       3      England   Overall     83
# 4       4      Belgium   Overall     83
# 5       0    Argentina    Attack     86
# 6       1      England    Attack     86
# 7       2       France    Attack     86
# 8       3       Brazil    Attack     85
# 9       4      Belgium    Attack     84
# 10      0       Brazil  Midfield     85
# 11      1        Spain  Midfield     85
# 12      2      Germany  Midfield     85
# 13      3        Italy  Midfield     84
# 14      4    Argentina  Midfield     84
# 15      0     Portugal   Defence     84
# 16      1       Brazil   Defence     83
# 17      2        Italy   Defence     83
# 18      3  Netherlands   Defence     83
# 19      4        Spain   Defence     83

# %% [markdown]
# Paises que figuran en el top 5 según el parámetro de calificación

# %%
d_team01['Country'].nunique()
# Out:
# 10

# %%
d_team01['Country'].value_counts()
# Out:
# Brazil         4
# Argentina      3
# Germany        2
# England        2
# Belgium        2
# Spain          2
# Italy          2
# France         1
# Portugal       1
# Netherlands    1
# Name: Country, dtype: int64

# %% [markdown]
# Es posible crear tablas dinámicas y mapas de calor

# %%
pd.pivot_table(d_team01,
               index = ['Country'],
               columns = ['Type'],
               values = ['index'],
               aggfunc = [np.sum])
# Out:
#                sum
#              index
# Type        Attack Defence Midfield Overall
# Country
# Argentina      0.0     NaN      4.0     1.0
# Belgium        4.0     NaN      NaN     4.0
# Brazil         3.0     1.0      0.0     0.0
# England        1.0     NaN      NaN     3.0
# France         2.0     NaN      NaN     NaN
# Germany        NaN     NaN      2.0     2.0
# Italy          NaN     2.0      3.0     NaN
# Netherlands    NaN     3.0      NaN     NaN
# Portugal       NaN     0.0      NaN     NaN
# Spain          NaN     4.0      1.0     NaN

# %% [markdown]
# ¿Por qué Alemania se encuentra en el tercer puesto del ranking general si solo destaca en el medio campo, mientras que España tiene más reconocimientos (y mejores) y no figura en dicho ranking?

# %% [markdown]
# Los argumentos de la pregunta son legítimos y la primera hipóstesis es que la asignación de puestos en el ranking general no solo es el resultado de evaluar el ataque, defensa o medio campo, existen más variables por analizar.

# %% [markdown]
# TAREA
#
# ¿Cuál es el método estadístico más adecuado para saber si una puntuación es significativa para asegurar un puesto alto en el ranking general?

# %%
d_team.head()
# Out:
#      ID    Country  Overall  Attack  Midfield  Defence  IntPrestige  Players  \
# 0  1370     Brazil       85      85        85       83           10       26
# 1  1337    Germany       84      84        85       82           10       26
# 2  1369  Argentina       84      86        84       82            9       26
# 3  1318    England       83      86        83       83            8       26
# 4  1325    Belgium       83      84        81       79            8       26
#
#    StartingAverageAge  AllTeamAverageAge
# 0                28.6               27.6
# 1                27.4               26.5
# 2                29.4               27.6
# 3                26.6               26.1
# 4                28.2               27.6

# %%
col_title = d_team.loc[:,'Overall':'Defence'].columns.tolist()

d_team01 = pd.DataFrame([])

top = 5

for i in col_title:
    
    aux01 = (d_team.loc[:,['Country','IntPrestige',i]].
                 sort_values(by = i, ascending = False, ignore_index = True).
                 head(top))
    
    aux02 = pd.melt(frame = aux01, id_vars = ['Country','IntPrestige'], value_vars = i, var_name = 'Type').reset_index()

    d_team01 = pd.concat([d_team01,aux02], ignore_index = True)

print(d_team01.head())

pd.pivot_table(d_team01,
               index = ['Country','IntPrestige'],
               columns = ['Type'],
               values = ['index'],
               aggfunc = [np.sum]).sort_values(by = 'IntPrestige', ascending = False)
# Out:
#    index    Country  IntPrestige     Type  value
# 0      0     Brazil           10  Overall     85
# 1      1  Argentina            9  Overall     84
# 2      2    Germany           10  Overall     84
# 3      3    England            8  Overall     83
# 4      4    Belgium            8  Overall     83
#                            sum
#                          index
# Type                    Attack Defence Midfield Overall
# Country     IntPrestige
# Brazil      10             3.0     1.0      0.0     0.0
# France      10             2.0     NaN      NaN     NaN
# Germany     10             NaN     NaN      2.0     2.0
# Argentina   9              0.0     NaN      4.0     1.0
# Italy       9              NaN     2.0      3.0     NaN
# Spain       9              NaN     4.0      1.0     NaN
# Belgium     8              4.0     NaN      NaN     4.0
# England     8              1.0     NaN      NaN     3.0
# Netherlands 8              NaN     3.0      NaN     NaN
# Portugal    8              NaN     0.0      NaN     NaN
